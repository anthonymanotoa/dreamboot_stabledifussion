# %% [markdown]
# <a href="https://colab.research.google.com/github/anthonymanotoa/dreamboot_stabledifussion/blob/main/DreamBooth_Stable_Diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15109 MiB, 15109 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate==0.12.0 transformers ftfy bitsandbytes gradio
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 163 kB 20.9 MB/s
#   Building wheel for diffusers (PEP 517) ... done
#      |████████████████████████████████| 18.7 MB 323 kB/s
#      |████████████████████████████████| 143 kB 37.0 MB/s
#      |████████████████████████████████| 4.9 MB 47.2 MB/s
#      |████████████████████████████████| 53 kB 1.8 MB/s
#      |████████████████████████████████| 55.9 MB 178 kB/s
#      |████████████████████████████████| 5.3 MB 51.7 MB/s
#      |████████████████████████████████| 6.6 MB 58.2 MB/s
#      |████████████████████████████████| 212 kB 64.5 MB/s
#      |████████████████████████████████| 57 kB 5.6 MB/s
#      |████████████████████████████████| 84 kB 3.6 MB/s
#      |████████████████████████████████| 2.3 MB 57.5 MB/s
#      |████████████████████████████████| 270 kB 70.5 MB/s
#      |████████████████████████████████| 54 kB 3.5 MB/s
#      |████████████████████████████████| 84 kB 3.4 MB/s
#      |████████████████████████████████| 55 kB 3.7 MB/s
#      |████████████████████████████████| 112 kB 72.4 MB/s
#      |████████████████████████████████| 63 kB 2.5 MB/s
#      |████████████████████████████████| 80 kB 9.4 MB/s
#      |████████████████████████████████| 68 kB 7.4 MB/s
#      |████████████████████████████████| 46 kB 4.2 MB/s
#      |████████████████████████████████| 4.0 MB 51.6 MB/s
#      |████████████████████████████████| 594 kB 70.3 MB/s
#      |████████████████████████████████| 856 kB 35.7 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
#@title Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/CompVis/stable-diffusion-v1-4), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
from huggingface_hub import notebook_login
# !git config --global credential.helper store
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %% [markdown]
# ### Install xformers from precompiled wheel.

# %%
# %pip install -q https://github.com/metrolobo/xformers_wheels/releases/download/1d31a3ac_various_6/xformers-0.0.14.dev0-cp37-cp37m-linux_x86_64.whl
# These were compiled on Tesla T4, should also work on P100, thanks to https://github.com/metrolobo

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@1d31a3a#egg=xformers
# Out:
#      |████████████████████████████████| 102.9 MB 115 kB/s

# %% [markdown]
# ## Settings and run

# %%
#@markdown Name/Path of the initial model.
MODEL_NAME = "CompVis/stable-diffusion-v1-4" #@param {type:"string"}

#@markdown Path for images of the concept for training.
INSTANCE_DIR = "/content/data/tony" #@param {type:"string"}
# !mkdir -p $INSTANCE_DIR

#@markdown A general name for class like dog for dog images.
CLASS_NAME = "guy" #@param {type:"string"}
CLASS_DIR = f"/content/data/{CLASS_NAME}"

#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = True #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/tony" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR

#@markdown sks is a rare identifier, feel free to replace it.
# Out:
# Mounted at /content/drive
# [*] Weights will be saved at /content/drive/MyDrive/stable_diffusion_weights/tony

# %%
#@markdown Upload your images by running this cell.

#@markdown OR

#@markdown You can use the file manager on the left panel to upload (drag and drop) to INSTANCE_DIR (it uploads faster)

import os
from google.colab import files
import shutil

uploaded = files.upload()
for filename in uploaded.keys():
    dst_path = os.path.join(INSTANCE_DIR, filename)
    shutil.move(filename, dst_path)

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --instance_data_dir=$INSTANCE_DIR \
  --class_data_dir=$CLASS_DIR \
  --output_dir=$OUTPUT_DIR \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --instance_prompt="photo of tony {CLASS_NAME}" \
  --class_prompt="photo of a {CLASS_NAME}" \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=20 \
  --sample_batch_size=4 \
  --max_train_steps=900
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--num_cpu_threads_per_process` was set to `1` to improve out-of-box performance
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading: 100% 543/543 [00:00<00:00, 553kB/s]
# Fetching 16 files:   0% 0/16 [00:00<?, ?it/s]
# Downloading: 100% 342/342 [00:00<00:00, 303kB/s]
# Fetching 16 files:   6% 1/16 [00:02<00:34,  2.29s/it]
# Downloading: 100% 4.56k/4.56k [00:00<00:00, 3.51MB/s]
# Fetching 16 files:  19% 3/16 [00:04<00:19,  1.47s/it]
# Downloading:   0% 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   1% 7.48M/1.22G [00:00<00:16, 74.8MB/s]
# Downloading:   1% 15.0M/1.22G [00:00<00:16, 73.6MB/s]
# Downloading:   2% 22.9M/1.22G [00:00<00:15, 76.0MB/s]
# Downloading:   3% 30.8M/1.22G [00:00<00:15, 77.4MB/s]
# Downloading:   3% 39.0M/1.22G [00:00<00:14, 79.0MB/s]
# Downloading:   4% 46.9M/1.22G [00:00<00:14, 78.1MB/s]
# Downloading:   5% 54.8M/1.22G [00:00<00:14, 78.3MB/s]
# Downloading:   5% 62.9M/1.22G [00:00<00:14, 79.3MB/s]
# Downloading:   6% 70.9M/1.22G [00:00<00:14, 79.5MB/s]
# Downloading:   7% 79.2M/1.22G [00:01<00:14, 80.4MB/s]
# Downloading:   7% 87.2M/1.22G [00:01<00:14, 80.1MB/s]
# Downloading:   8% 95.2M/1.22G [00:01<00:14, 78.0MB/s]
# Downloading:   8% 103M/1.22G [00:01<00:14, 77.2MB/s]
# Downloading:   9% 111M/1.22G [00:01<00:14, 77.6MB/s]
# Downloading:  10% 119M/1.22G [00:01<00:14, 78.0MB/s]
# Downloading:  10% 127M/1.22G [00:01<00:15, 72.5MB/s]
# Downloading:  11% 134M/1.22G [00:01<00:14, 74.1MB/s]
# Downloading:  12% 142M/1.22G [00:01<00:14, 74.1MB/s]
# Downloading:  12% 149M/1.22G [00:01<00:14, 74.4MB/s]
# Downloading:  13% 157M/1.22G [00:02<00:15, 67.8MB/s]
# Downloading:  14% 164M/1.22G [00:02<00:15, 69.5MB/s]
# Downloading:  14% 172M/1.22G [00:02<00:14, 70.6MB/s]
# Downloading:  15% 179M/1.22G [00:02<00:14, 71.9MB/s]
# Downloading:  15% 187M/1.22G [00:02<00:14, 72.9MB/s]
# Downloading:  95% 1.15G/1.22G [00:16<00:00, 72.8MB/s]
# Downloading:  95% 1.16G/1.22G [00:16<00:00, 74.3MB/s]
# Downloading:  96% 1.17G/1.22G [00:16<00:00, 73.4MB/s]
# Downloading:  97% 1.17G/1.22G [00:16<00:00, 72.2MB/s]
# Downloading:  97% 1.18G/1.22G [00:16<00:00, 75.2MB/s]
# Downloading:  98% 1.19G/1.22G [00:16<00:00, 73.8MB/s]
# Downloading:  98% 1.20G/1.22G [00:16<00:00, 76.0MB/s]
# Downloading:  99% 1.21G/1.22G [00:16<00:00, 71.8MB/s]
# Downloading: 100% 1.22G/1.22G [00:16<00:00, 71.8MB/s]
# Fetching 16 files:  25% 4/16 [00:22<01:26,  7.25s/it]
# Downloading: 100% 209/209 [00:00<00:00, 188kB/s]
# Fetching 16 files:  38% 6/16 [00:26<00:42,  4.21s/it]
# Downloading: 100% 592/592 [00:00<00:00, 399kB/s]
# Fetching 16 files:  44% 7/16 [00:28<00:32,  3.62s/it]
# Downloading:   0% 0.00/492M [00:00<?, ?B/s]
# Downloading:   1% 4.17M/492M [00:00<00:11, 41.7MB/s]
# Downloading:   2% 8.61M/492M [00:00<00:11, 43.3MB/s]
# Downloading:   3% 12.9M/492M [00:00<00:11, 43.1MB/s]
# Downloading:   4% 17.4M/492M [00:00<00:10, 43.8MB/s]
# Downloading:   4% 21.9M/492M [00:00<00:10, 44.3MB/s]
# Downloading:   5% 26.4M/492M [00:00<00:10, 43.2MB/s]
# Downloading:   6% 30.8M/492M [00:00<00:10, 43.7MB/s]
# Downloading:   7% 35.4M/492M [00:00<00:10, 44.2MB/s]
# Downloading:   8% 40.1M/492M [00:00<00:10, 45.2MB/s]
# Downloading:   9% 44.9M/492M [00:01<00:09, 46.0MB/s]
# Downloading:  10% 49.6M/492M [00:01<00:09, 46.3MB/s]
# Downloading:  11% 54.4M/492M [00:01<00:09, 46.8MB/s]
# Downloading:  12% 60.7M/492M [00:01<00:08, 51.7MB/s]
# Downloading:  14% 68.1M/492M [00:01<00:07, 58.5MB/s]
# Downloading:  15% 75.6M/492M [00:01<00:06, 63.4MB/s]
# Downloading:  17% 83.0M/492M [00:01<00:06, 66.7MB/s]
# Downloading:  18% 89.7M/492M [00:01<00:06, 66.7MB/s]
# Downloading:  20% 97.5M/492M [00:01<00:05, 70.1MB/s]
# Downloading:  21% 105M/492M [00:01<00:05, 70.6MB/s]
# Downloading:  23% 112M/492M [00:02<00:05, 72.4MB/s]
# Downloading:  24% 120M/492M [00:02<00:05, 72.1MB/s]
# Downloading:  26% 127M/492M [00:02<00:05, 69.2MB/s]
# Downloading:  27% 134M/492M [00:02<00:05, 70.4MB/s]
# Downloading:  29% 142M/492M [00:02<00:04, 72.2MB/s]
# Downloading:  30% 150M/492M [00:02<00:04, 74.6MB/s]
# Downloading:  32% 157M/492M [00:02<00:04, 70.7MB/s]
# Downloading:  33% 164M/492M [00:02<00:04, 68.2MB/s]
# Downloading:  35% 172M/492M [00:02<00:04, 70.6MB/s]
# Downloading:  36% 179M/492M [00:02<00:04, 70.6MB/s]
# Downloading:  38% 187M/492M [00:03<00:04, 73.4MB/s]
# Downloading:  40% 195M/492M [00:03<00:03, 74.7MB/s]
# Downloading:  41% 203M/492M [00:03<00:03, 76.9MB/s]
# Downloading:  43% 211M/492M [00:03<00:03, 78.1MB/s]
# Downloading:  45% 219M/492M [00:03<00:03, 78.0MB/s]
# Downloading:  46% 227M/492M [00:03<00:04, 65.2MB/s]
# Downloading:  47% 234M/492M [00:03<00:04, 64.5MB/s]
# Downloading:  49% 242M/492M [00:03<00:03, 67.8MB/s]
# Downloading:  51% 249M/492M [00:03<00:03, 70.5MB/s]
# Downloading:  52% 257M/492M [00:04<00:03, 71.3MB/s]
# Downloading:  54% 264M/492M [00:04<00:03, 73.2MB/s]
# Downloading:  55% 272M/492M [00:04<00:02, 74.3MB/s]
# Downloading:  57% 280M/492M [00:04<00:02, 74.1MB/s]
# Downloading:  58% 288M/492M [00:04<00:02, 76.1MB/s]
# Downloading:  60% 295M/492M [00:04<00:02, 76.7MB/s]
# Downloading:  62% 303M/492M [00:04<00:02, 74.5MB/s]
# Downloading:  63% 311M/492M [00:04<00:02, 71.7MB/s]
# Downloading:  65% 318M/492M [00:04<00:02, 73.2MB/s]
# Downloading:  66% 326M/492M [00:04<00:02, 74.4MB/s]
# Downloading:  68% 334M/492M [00:05<00:02, 74.8MB/s]
# Downloading:  69% 341M/492M [00:05<00:02, 72.0MB/s]
# Downloading:  71% 348M/492M [00:05<00:02, 71.9MB/s]
# Downloading:  72% 356M/492M [00:05<00:01, 72.1MB/s]
# Downloading:  74% 363M/492M [00:05<00:01, 73.1MB/s]
# Downloading:  75% 371M/492M [00:05<00:01, 70.1MB/s]
# Downloading:  77% 378M/492M [00:05<00:01, 72.7MB/s]
# Downloading:  78% 386M/492M [00:05<00:01, 71.5MB/s]
# Downloading:  80% 393M/492M [00:05<00:01, 72.8MB/s]
# Downloading:  81% 401M/492M [00:05<00:01, 74.2MB/s]
# Downloading:  83% 409M/492M [00:06<00:01, 70.0MB/s]
# Downloading:  84% 416M/492M [00:06<00:01, 68.4MB/s]
# Downloading:  86% 424M/492M [00:06<00:00, 72.1MB/s]
# Downloading:  88% 431M/492M [00:06<00:00, 73.0MB/s]
# Downloading:  89% 439M/492M [00:06<00:00, 74.4MB/s]
# Downloading:  91% 446M/492M [00:06<00:00, 70.4MB/s]
# Downloading:  92% 454M/492M [00:06<00:00, 71.8MB/s]
# Downloading:  94% 461M/492M [00:06<00:00, 71.3MB/s]
# Downloading:  95% 469M/492M [00:06<00:00, 72.3MB/s]
# Downloading:  97% 476M/492M [00:07<00:00, 72.0MB/s]
# Downloading:  98% 483M/492M [00:07<00:00, 72.4MB/s]
# Downloading: 100% 492M/492M [00:07<00:00, 67.8MB/s]
# Fetching 16 files:  50% 8/16 [00:37<00:40,  5.11s/it]
# Downloading:   0% 0.00/525k [00:00<?, ?B/s]
# Downloading:   6% 32.8k/525k [00:00<00:03, 143kB/s]
# Downloading:  16% 86.0k/525k [00:00<00:02, 195kB/s]
# Downloading:  37% 193k/525k [00:00<00:01, 317kB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 567kB/s]
# Fetching 16 files:  56% 9/16 [00:40<00:32,  4.63s/it]
# Downloading: 100% 472/472 [00:00<00:00, 424kB/s]
# Fetching 16 files:  62% 10/16 [00:43<00:23,  3.94s/it]
# Downloading: 100% 806/806 [00:00<00:00, 718kB/s]
# Fetching 16 files:  69% 11/16 [00:45<00:17,  3.45s/it]
# Downloading:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0% 4.10k/1.06M [00:00<00:59, 17.6kB/s]
# Downloading:   3% 32.8k/1.06M [00:00<00:12, 79.7kB/s]
# Downloading:   8% 86.0k/1.06M [00:00<00:06, 148kB/s]
# Downloading:  19% 201k/1.06M [00:00<00:03, 284kB/s]
# Downloading:  42% 446k/1.06M [00:01<00:01, 562kB/s]
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 757kB/s]
# Fetching 16 files:  75% 12/16 [00:49<00:14,  3.54s/it]
# Downloading: 100% 743/743 [00:00<00:00, 684kB/s]
# Fetching 16 files:  81% 13/16 [00:51<00:09,  3.19s/it]
# Downloading:   0% 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0% 7.12M/3.44G [00:00<00:48, 71.2MB/s]
# Downloading:   0% 14.2M/3.44G [00:00<00:48, 70.5MB/s]
# Downloading:   1% 21.9M/3.44G [00:00<00:46, 73.4MB/s]
# Downloading:   1% 30.1M/3.44G [00:00<00:44, 76.7MB/s]
# Downloading:   1% 38.1M/3.44G [00:00<00:43, 77.9MB/s]
# Downloading:   1% 45.9M/3.44G [00:00<00:44, 77.1MB/s]
# Downloading:   2% 54.0M/3.44G [00:00<00:43, 78.3MB/s]
# Downloading:   2% 61.9M/3.44G [00:00<00:42, 78.6MB/s]
# Downloading:   2% 69.8M/3.44G [00:00<00:42, 78.5MB/s]
# Downloading:   2% 77.6M/3.44G [00:01<00:43, 77.8MB/s]
# Downloading:   2% 85.7M/3.44G [00:01<00:42, 78.6MB/s]
# Downloading:   3% 93.6M/3.44G [00:01<00:43, 76.4MB/s]
# Downloading:   3% 102M/3.44G [00:01<00:42, 77.7MB/s]
# Downloading:   3% 109M/3.44G [00:01<00:42, 77.8MB/s]
# Downloading:   3% 117M/3.44G [00:01<00:42, 77.7MB/s]
# Downloading:   4% 125M/3.44G [00:01<00:46, 71.5MB/s]
# Downloading:   4% 133M/3.44G [00:01<00:45, 72.4MB/s]
# Downloading:   4% 140M/3.44G [00:01<00:44, 73.9MB/s]
# Downloading:   4% 148M/3.44G [00:01<00:43, 75.7MB/s]
# Downloading:   5% 156M/3.44G [00:02<00:45, 71.7MB/s]
# Downloading:   5% 164M/3.44G [00:02<00:44, 73.9MB/s]
# Downloading:   5% 171M/3.44G [00:02<00:44, 73.3MB/s]
# Downloading:   5% 179M/3.44G [00:02<00:44, 73.8MB/s]
# Downloading:   5% 186M/3.44G [00:02<00:46, 70.1MB/s]
# Downloading:   6% 194M/3.44G [00:02<00:44, 72.6MB/s]
# Downloading:   6% 202M/3.44G [00:02<00:44, 72.5MB/s]
# Downloading:   6% 209M/3.44G [00:02<00:44, 72.3MB/s]
# Downloading:   6% 217M/3.44G [00:02<00:43, 73.8MB/s]
# Downloading:   7% 224M/3.44G [00:02<00:43, 74.2MB/s]
# Downloading:   7% 232M/3.44G [00:03<00:42, 75.1MB/s]
# Downloading:   7% 240M/3.44G [00:03<00:42, 75.8MB/s]
# Downloading:   7% 247M/3.44G [00:03<00:43, 73.1MB/s]
# Downloading:   7% 254M/3.44G [00:03<00:45, 70.6MB/s]
# Downloading:   8% 262M/3.44G [00:03<00:46, 68.1MB/s]
# Downloading:   8% 268M/3.44G [00:03<00:46, 67.9MB/s]
# Downloading:   8% 276M/3.44G [00:03<00:44, 70.3MB/s]
# Downloading:   8% 283M/3.44G [00:03<00:44, 71.5MB/s]
# Downloading:   8% 291M/3.44G [00:03<00:43, 72.6MB/s]
# Downloading:   9% 299M/3.44G [00:04<00:42, 73.7MB/s]
# Downloading:   9% 306M/3.44G [00:04<00:52, 59.3MB/s]
# Downloading:   9% 312M/3.44G [00:04<01:00, 51.8MB/s]
# Downloading:   9% 318M/3.44G [00:04<01:10, 44.0MB/s]
# Downloading:   9% 326M/3.44G [00:04<00:59, 52.2MB/s]
# Downloading:  10% 332M/3.44G [00:04<01:01, 50.3MB/s]
# Downloading:  10% 340M/3.44G [00:04<00:54, 57.0MB/s]
# Downloading:  10% 347M/3.44G [00:04<00:50, 61.5MB/s]
# Downloading:  10% 355M/3.44G [00:05<00:47, 65.5MB/s]
# Downloading:  11% 363M/3.44G [00:05<00:44, 69.3MB/s]
# Downloading:  11% 370M/3.44G [00:05<00:43, 70.5MB/s]
# Downloading:  11% 378M/3.44G [00:05<00:42, 71.7MB/s]
# Downloading:  11% 386M/3.44G [00:05<00:41, 74.3MB/s]
# Downloading:  11% 394M/3.44G [00:05<00:40, 76.1MB/s]
# Downloading:  12% 402M/3.44G [00:05<00:39, 77.2MB/s]
# Downloading:  12% 409M/3.44G [00:05<00:39, 77.3MB/s]
# Downloading:  12% 417M/3.44G [00:05<00:38, 78.3MB/s]
# Downloading:  12% 425M/3.44G [00:06<00:39, 77.1MB/s]
# Downloading:  13% 433M/3.44G [00:06<00:39, 76.7MB/s]
# Downloading:  13% 441M/3.44G [00:06<00:39, 76.4MB/s]
# Downloading:  13% 448M/3.44G [00:06<00:40, 73.9MB/s]
# Downloading:  13% 456M/3.44G [00:06<00:43, 68.9MB/s]
# Downloading:  13% 464M/3.44G [00:06<00:41, 71.2MB/s]
# Downloading:  14% 471M/3.44G [00:06<00:41, 71.1MB/s]
# Downloading:  14% 478M/3.44G [00:06<00:44, 65.9MB/s]
# Downloading:  14% 485M/3.44G [00:06<00:43, 68.5MB/s]
# Downloading:  14% 493M/3.44G [00:06<00:41, 70.5MB/s]
# Downloading:  15% 501M/3.44G [00:07<00:40, 72.1MB/s]
# Downloading:  15% 508M/3.44G [00:07<00:39, 73.9MB/s]
# Downloading:  15% 516M/3.44G [00:07<00:39, 74.1MB/s]
# Downloading:  15% 523M/3.44G [00:07<00:39, 72.9MB/s]
# Downloading:  15% 531M/3.44G [00:07<00:39, 73.4MB/s]
# Downloading:  16% 538M/3.44G [00:07<00:39, 72.7MB/s]
# Downloading:  16% 545M/3.44G [00:07<00:40, 71.0MB/s]
# Downloading:  16% 553M/3.44G [00:07<00:39, 72.6MB/s]
# Downloading:  16% 560M/3.44G [00:07<00:39, 72.8MB/s]
# Downloading:  17% 568M/3.44G [00:07<00:38, 74.3MB/s]
# Downloading:  17% 576M/3.44G [00:08<00:38, 74.3MB/s]
# Downloading:  17% 583M/3.44G [00:08<00:38, 74.9MB/s]
# Downloading:  17% 591M/3.44G [00:08<00:38, 74.7MB/s]
# Downloading:  17% 598M/3.44G [00:08<00:38, 74.3MB/s]
# Downloading:  18% 606M/3.44G [00:08<00:37, 76.2MB/s]
# Downloading:  18% 614M/3.44G [00:08<00:37, 75.5MB/s]
# Downloading:  18% 621M/3.44G [00:08<00:40, 69.9MB/s]
# Downloading:  18% 629M/3.44G [00:08<00:39, 72.0MB/s]
# Downloading:  19% 637M/3.44G [00:08<00:38, 72.5MB/s]
# Downloading:  19% 644M/3.44G [00:09<00:39, 70.4MB/s]
# Downloading:  19% 652M/3.44G [00:09<00:38, 71.9MB/s]
# Downloading:  19% 660M/3.44G [00:09<00:37, 74.3MB/s]
# Downloading:  19% 667M/3.44G [00:09<00:36, 75.9MB/s]
# Downloading:  20% 675M/3.44G [00:09<00:39, 70.0MB/s]
# Downloading:  20% 683M/3.44G [00:09<00:37, 72.7MB/s]
# Downloading:  20% 691M/3.44G [00:09<00:36, 75.3MB/s]
# Downloading:  20% 699M/3.44G [00:09<00:36, 75.1MB/s]
# Downloading:  21% 706M/3.44G [00:09<00:38, 70.9MB/s]
# Downloading:  21% 714M/3.44G [00:09<00:39, 68.9MB/s]
# Downloading:  21% 721M/3.44G [00:10<00:38, 70.0MB/s]
# Downloading:  21% 729M/3.44G [00:10<00:37, 72.5MB/s]
# Downloading:  21% 737M/3.44G [00:10<00:36, 74.2MB/s]
# Downloading:  22% 744M/3.44G [00:10<00:37, 71.9MB/s]
# Downloading:  22% 752M/3.44G [00:10<00:36, 74.1MB/s]
# Downloading:  22% 760M/3.44G [00:10<00:35, 75.5MB/s]
# Downloading:  22% 768M/3.44G [00:10<00:35, 75.9MB/s]
# Downloading:  23% 776M/3.44G [00:10<00:34, 77.4MB/s]
# Downloading:  23% 784M/3.44G [00:10<00:34, 78.1MB/s]
# Downloading:  23% 792M/3.44G [00:11<00:34, 77.4MB/s]
# Downloading:  23% 800M/3.44G [00:11<00:33, 78.4MB/s]
# Downloading:  23% 807M/3.44G [00:11<00:33, 78.6MB/s]
# Downloading:  24% 815M/3.44G [00:11<00:33, 78.2MB/s]
# Downloading:  24% 823M/3.44G [00:11<00:49, 52.5MB/s]
# Downloading:  51% 1.75G/3.44G [00:24<00:24, 70.1MB/s]
# Downloading:  51% 1.76G/3.44G [00:24<00:23, 70.7MB/s]
# Downloading:  51% 1.76G/3.44G [00:24<00:23, 71.3MB/s]
# Downloading:  52% 1.77G/3.44G [00:24<00:22, 73.5MB/s]
# Downloading:  52% 1.78G/3.44G [00:25<00:22, 73.0MB/s]
# Downloading:  52% 1.79G/3.44G [00:25<00:23, 71.4MB/s]
# Downloading:  52% 1.79G/3.44G [00:25<00:22, 73.8MB/s]
# Downloading:  52% 1.80G/3.44G [00:25<00:22, 74.1MB/s]
# Downloading:  53% 1.81G/3.44G [00:25<00:21, 76.2MB/s]
# Downloading:  53% 1.82G/3.44G [00:25<00:24, 66.8MB/s]
# Downloading:  53% 1.83G/3.44G [00:25<00:23, 68.2MB/s]
# Downloading:  53% 1.83G/3.44G [00:25<00:23, 67.7MB/s]
# Downloading:  53% 1.84G/3.44G [00:25<00:22, 69.7MB/s]
# Downloading:  54% 1.85G/3.44G [00:25<00:22, 70.9MB/s]
# Downloading:  54% 1.85G/3.44G [00:26<00:21, 73.6MB/s]
# Downloading:  54% 1.86G/3.44G [00:26<00:21, 73.2MB/s]
# Downloading:  54% 1.87G/3.44G [00:26<00:21, 74.0MB/s]
# Downloading:  55% 1.88G/3.44G [00:26<00:20, 74.7MB/s]
# Downloading:  55% 1.89G/3.44G [00:26<00:20, 74.3MB/s]
# Downloading:  55% 1.89G/3.44G [00:26<00:20, 74.4MB/s]
# Downloading:  55% 1.90G/3.44G [00:26<00:20, 74.0MB/s]
# Downloading:  55% 1.91G/3.44G [00:26<00:21, 71.7MB/s]
# Downloading:  56% 1.92G/3.44G [00:26<00:20, 73.3MB/s]
# Downloading:  56% 1.92G/3.44G [00:26<00:20, 74.1MB/s]
# Downloading:  56% 1.93G/3.44G [00:27<00:20, 73.2MB/s]
# Downloading:  56% 1.94G/3.44G [00:27<00:22, 66.7MB/s]
# Downloading:  57% 1.95G/3.44G [00:27<00:21, 69.9MB/s]
# Downloading:  57% 1.95G/3.44G [00:27<00:21, 70.5MB/s]
# Downloading:  57% 1.96G/3.44G [00:27<00:22, 64.8MB/s]
# Downloading:  57% 1.97G/3.44G [00:27<00:21, 68.9MB/s]
# Downloading:  57% 1.97G/3.44G [00:27<00:21, 67.7MB/s]
# Downloading:  58% 1.98G/3.44G [00:27<00:20, 69.6MB/s]
# Downloading:  58% 1.99G/3.44G [00:27<00:20, 70.6MB/s]
# Downloading:  58% 2.00G/3.44G [00:28<00:20, 71.9MB/s]
# Downloading:  58% 2.00G/3.44G [00:28<00:19, 74.0MB/s]
# Downloading:  59% 2.01G/3.44G [00:28<00:19, 74.8MB/s]
# Downloading:  59% 2.02G/3.44G [00:28<00:18, 76.5MB/s]
# Downloading:  59% 2.03G/3.44G [00:28<00:18, 77.1MB/s]
# Downloading:  59% 2.04G/3.44G [00:28<00:20, 68.2MB/s]
# Downloading:  59% 2.04G/3.44G [00:28<00:19, 71.3MB/s]
# Downloading:  69% 2.36G/3.44G [00:33<00:14, 72.8MB/s]
# Downloading:  69% 2.36G/3.44G [00:33<00:14, 74.9MB/s]
# Downloading:  69% 2.37G/3.44G [00:33<00:14, 74.4MB/s]
# Downloading:  69% 2.38G/3.44G [00:33<00:14, 74.5MB/s]
# Downloading:  69% 2.39G/3.44G [00:33<00:14, 72.2MB/s]
# Downloading:  70% 2.39G/3.44G [00:34<00:54, 19.0MB/s]
# Downloading:  70% 2.40G/3.44G [00:34<00:45, 22.7MB/s]
# Downloading:  70% 2.41G/3.44G [00:34<00:37, 27.3MB/s]
# Downloading:  70% 2.41G/3.44G [00:34<00:30, 33.2MB/s]
# Downloading:  70% 2.42G/3.44G [00:34<00:25, 39.5MB/s]
# Downloading:  71% 2.43G/3.44G [00:35<00:21, 46.6MB/s]
# Downloading:  71% 2.43G/3.44G [00:35<00:19, 52.6MB/s]
# Downloading:  71% 2.44G/3.44G [00:35<00:17, 57.7MB/s]
# Downloading:  71% 2.45G/3.44G [00:35<00:15, 62.2MB/s]
# Downloading:  71% 2.46G/3.44G [00:35<00:14, 65.9MB/s]
# Downloading:  72% 2.46G/3.44G [00:35<00:14, 69.0MB/s]
# Downloading:  72% 2.47G/3.44G [00:35<00:15, 62.5MB/s]
# Downloading:  72% 2.48G/3.44G [00:35<00:14, 66.1MB/s]
# Downloading:  72% 2.49G/3.44G [00:35<00:13, 69.2MB/s]
# Downloading:  73% 2.49G/3.44G [00:35<00:13, 70.2MB/s]
# Downloading:  73% 2.50G/3.44G [00:36<00:13, 71.1MB/s]
# Downloading:  73% 2.51G/3.44G [00:36<00:13, 71.2MB/s]
# Downloading:  73% 2.52G/3.44G [00:36<00:12, 72.0MB/s]
# Downloading:  73% 2.52G/3.44G [00:36<00:12, 73.1MB/s]
# Downloading:  74% 2.53G/3.44G [00:36<00:14, 62.3MB/s]
# Downloading:  74% 2.54G/3.44G [00:36<00:13, 65.1MB/s]
# Downloading:  74% 2.55G/3.44G [00:36<00:13, 67.9MB/s]
# Downloading:  74% 2.55G/3.44G [00:36<00:12, 69.7MB/s]
# Downloading:  75% 2.56G/3.44G [00:36<00:12, 72.9MB/s]
# Downloading:  75% 2.57G/3.44G [00:37<00:12, 72.2MB/s]
# Downloading:  75% 2.58G/3.44G [00:37<00:11, 72.4MB/s]
# Downloading:  75% 2.58G/3.44G [00:37<00:11, 73.2MB/s]
# Downloading:  75% 2.59G/3.44G [00:37<00:11, 72.8MB/s]
# Downloading:  76% 2.60G/3.44G [00:37<00:11, 73.0MB/s]
# Downloading:  76% 2.61G/3.44G [00:37<00:11, 72.4MB/s]
# Downloading:  76% 2.61G/3.44G [00:37<00:11, 71.5MB/s]
# Downloading:  76% 2.62G/3.44G [00:37<00:11, 70.8MB/s]
# Downloading:  76% 2.63G/3.44G [00:37<00:11, 72.8MB/s]
# Downloading:  77% 2.64G/3.44G [00:37<00:10, 73.9MB/s]
# Downloading:  77% 2.64G/3.44G [00:38<00:11, 71.7MB/s]
# Downloading:  77% 2.65G/3.44G [00:38<00:12, 64.3MB/s]
# Downloading:  77% 2.66G/3.44G [00:38<00:11, 67.5MB/s]
# Downloading:  78% 2.67G/3.44G [00:38<00:11, 69.9MB/s]
# Downloading:  78% 2.67G/3.44G [00:38<00:12, 61.5MB/s]
# Downloading:  78% 2.68G/3.44G [00:38<00:11, 64.9MB/s]
# Downloading:  78% 2.69G/3.44G [00:38<00:11, 66.2MB/s]
# Downloading:  78% 2.69G/3.44G [00:38<00:11, 67.1MB/s]
# Downloading:  79% 2.70G/3.44G [00:38<00:10, 69.9MB/s]
# Downloading:  79% 2.71G/3.44G [00:39<00:10, 70.0MB/s]
# Downloading:  79% 2.72G/3.44G [00:39<00:10, 71.2MB/s]
# Downloading:  79% 2.72G/3.44G [00:39<00:09, 72.9MB/s]
# Downloading:  79% 2.73G/3.44G [00:39<00:09, 72.9MB/s]
# Downloading:  80% 2.74G/3.44G [00:39<00:09, 73.9MB/s]
# Downloading:  80% 2.75G/3.44G [00:39<00:09, 74.0MB/s]
# Downloading:  80% 2.75G/3.44G [00:39<00:09, 71.7MB/s]
# Downloading:  80% 2.76G/3.44G [00:39<00:09, 68.6MB/s]
# Downloading:  81% 2.77G/3.44G [00:39<00:09, 70.2MB/s]
# Downloading:  81% 2.78G/3.44G [00:39<00:09, 71.8MB/s]
# Downloading:  81% 2.78G/3.44G [00:40<00:09, 71.0MB/s]
# Downloading:  81% 2.79G/3.44G [00:40<00:10, 64.0MB/s]
# Downloading:  81% 2.80G/3.44G [00:40<00:09, 66.3MB/s]
# Downloading:  82% 2.81G/3.44G [00:40<00:09, 68.3MB/s]
# Downloading:  82% 2.81G/3.44G [00:40<00:08, 70.0MB/s]
# Downloading:  82% 2.82G/3.44G [00:40<00:09, 66.1MB/s]
# Downloading:  82% 2.83G/3.44G [00:40<00:09, 67.8MB/s]
# Downloading:  82% 2.83G/3.44G [00:40<00:08, 69.2MB/s]
# Downloading:  83% 2.84G/3.44G [00:40<00:08, 71.3MB/s]
# Downloading:  83% 2.85G/3.44G [00:41<00:08, 71.5MB/s]
# Downloading:  83% 2.86G/3.44G [00:41<00:08, 66.6MB/s]
# Downloading:  83% 2.86G/3.44G [00:41<00:08, 69.0MB/s]
# Downloading:  84% 2.87G/3.44G [00:41<00:07, 71.1MB/s]
# Downloading:  84% 2.88G/3.44G [00:41<00:07, 71.6MB/s]
# Downloading:  84% 2.89G/3.44G [00:41<00:08, 64.7MB/s]
# Downloading:  84% 2.89G/3.44G [00:41<00:08, 63.4MB/s]
# Downloading:  84% 2.90G/3.44G [00:41<00:08, 65.2MB/s]
# Downloading:  85% 2.91G/3.44G [00:42<00:30, 17.7MB/s]
# Downloading:  85% 2.91G/3.44G [00:42<00:22, 23.2MB/s]
# Downloading:  85% 2.92G/3.44G [00:43<00:30, 17.0MB/s]
# Downloading:  85% 2.92G/3.44G [00:44<00:37, 13.9MB/s]
# Downloading:  85% 2.93G/3.44G [00:44<00:26, 18.9MB/s]
# Downloading:  85% 2.94G/3.44G [00:44<00:19, 25.4MB/s]
# Downloading:  86% 2.94G/3.44G [00:44<00:28, 17.2MB/s]
# Downloading:  86% 2.95G/3.44G [00:45<00:36, 13.6MB/s]
# Downloading:  86% 2.95G/3.44G [00:45<00:24, 19.4MB/s]
# Downloading:  86% 2.96G/3.44G [00:45<00:18, 26.2MB/s]
# Downloading:  86% 2.97G/3.44G [00:45<00:14, 32.8MB/s]
# Downloading:  87% 2.98G/3.44G [00:45<00:11, 40.6MB/s]
# Downloading:  87% 2.98G/3.44G [00:46<00:29, 15.7MB/s]
# Downloading:  87% 2.99G/3.44G [00:46<00:23, 19.3MB/s]
# Downloading:  87% 2.99G/3.44G [00:47<00:40, 10.9MB/s]
# Downloading:  87% 3.00G/3.44G [00:48<00:28, 15.3MB/s]
# Downloading:  87% 3.01G/3.44G [00:48<00:39, 10.8MB/s]
# Downloading:  88% 3.01G/3.44G [00:49<00:37, 11.3MB/s]
# Downloading:  88% 3.01G/3.44G [00:49<00:27, 15.6MB/s]
# Downloading:  88% 3.02G/3.44G [00:49<00:19, 21.8MB/s]
# Downloading:  88% 3.03G/3.44G [00:50<00:28, 14.4MB/s]
# Downloading:  88% 3.03G/3.44G [00:50<00:32, 12.6MB/s]
# Downloading:  88% 3.04G/3.44G [00:50<00:22, 17.7MB/s]
# Downloading:  88% 3.04G/3.44G [00:50<00:22, 17.9MB/s]
# Downloading:  89% 3.04G/3.44G [00:51<00:40, 9.62MB/s]
# Downloading:  89% 3.05G/3.44G [00:51<00:29, 13.2MB/s]
# Downloading:  89% 3.06G/3.44G [00:51<00:19, 19.3MB/s]
# Downloading:  89% 3.06G/3.44G [00:51<00:15, 24.3MB/s]
# Downloading:  89% 3.07G/3.44G [00:52<00:32, 11.5MB/s]
# Downloading:  89% 3.07G/3.44G [00:53<00:22, 16.4MB/s]
# Downloading:  90% 3.08G/3.44G [00:53<00:15, 22.8MB/s]
# Downloading:  90% 3.09G/3.44G [00:53<00:12, 28.3MB/s]
# Downloading:  90% 3.10G/3.44G [00:53<00:09, 35.4MB/s]
# Downloading:  90% 3.10G/3.44G [00:53<00:07, 42.6MB/s]
# Downloading:  90% 3.11G/3.44G [00:53<00:06, 49.2MB/s]
# Downloading:  91% 3.12G/3.44G [00:53<00:05, 55.0MB/s]
# Downloading:  91% 3.13G/3.44G [00:53<00:05, 60.4MB/s]
# Downloading:  91% 3.13G/3.44G [00:53<00:04, 63.0MB/s]
# Downloading:  91% 3.14G/3.44G [00:53<00:04, 62.7MB/s]
# Downloading:  92% 3.15G/3.44G [00:54<00:05, 54.7MB/s]
# Downloading:  92% 3.15G/3.44G [00:54<00:04, 59.2MB/s]
# Downloading:  92% 3.16G/3.44G [00:54<00:04, 62.2MB/s]
# Downloading:  92% 3.17G/3.44G [00:54<00:04, 65.2MB/s]
# Downloading:  92% 3.18G/3.44G [00:54<00:03, 67.7MB/s]
# Downloading:  93% 3.18G/3.44G [00:54<00:03, 69.2MB/s]
# Downloading:  93% 3.19G/3.44G [00:54<00:03, 72.3MB/s]
# Downloading:  93% 3.20G/3.44G [00:54<00:03, 74.1MB/s]
# Downloading:  93% 3.21G/3.44G [00:54<00:03, 65.0MB/s]
# Downloading:  93% 3.21G/3.44G [00:55<00:03, 67.6MB/s]
# Downloading:  94% 3.22G/3.44G [00:55<00:03, 70.3MB/s]
# Downloading:  94% 3.23G/3.44G [00:55<00:03, 68.4MB/s]
# Downloading:  94% 3.24G/3.44G [00:55<00:02, 69.8MB/s]
# Downloading:  94% 3.24G/3.44G [00:55<00:02, 71.5MB/s]
# Downloading:  95% 3.25G/3.44G [00:55<00:02, 71.2MB/s]
# Downloading:  95% 3.26G/3.44G [00:55<00:02, 73.0MB/s]
# Downloading:  95% 3.27G/3.44G [00:55<00:02, 73.1MB/s]
# Downloading:  95% 3.27G/3.44G [00:55<00:02, 73.5MB/s]
# Downloading:  95% 3.28G/3.44G [00:55<00:02, 73.6MB/s]
# Downloading:  96% 3.29G/3.44G [00:56<00:01, 75.5MB/s]
# Downloading:  96% 3.30G/3.44G [00:56<00:01, 74.8MB/s]
# Downloading:  96% 3.30G/3.44G [00:56<00:01, 72.9MB/s]
# Downloading:  96% 3.31G/3.44G [00:56<00:01, 74.0MB/s]
# Downloading:  97% 3.32G/3.44G [00:56<00:01, 73.2MB/s]
# Downloading:  97% 3.33G/3.44G [00:56<00:01, 66.0MB/s]
# Downloading:  97% 3.33G/3.44G [00:56<00:01, 67.4MB/s]
# Downloading:  97% 3.34G/3.44G [00:56<00:01, 65.1MB/s]
# Downloading:  97% 3.35G/3.44G [00:56<00:01, 67.9MB/s]
# Downloading:  98% 3.35G/3.44G [00:57<00:01, 68.3MB/s]
# Downloading:  98% 3.36G/3.44G [00:57<00:01, 71.9MB/s]
# Downloading:  98% 3.37G/3.44G [00:57<00:00, 73.6MB/s]
# Downloading:  98% 3.38G/3.44G [00:57<00:00, 67.1MB/s]
# Downloading:  98% 3.39G/3.44G [00:57<00:00, 70.4MB/s]
# Downloading:  99% 3.39G/3.44G [00:57<00:00, 73.4MB/s]
# Downloading:  99% 3.40G/3.44G [00:57<00:00, 73.1MB/s]
# Downloading:  99% 3.41G/3.44G [00:57<00:00, 73.5MB/s]
# Downloading:  99% 3.42G/3.44G [00:57<00:00, 75.5MB/s]
# Downloading: 100% 3.42G/3.44G [00:57<00:00, 75.2MB/s]
# Downloading: 100% 3.44G/3.44G [00:58<00:00, 59.1MB/s]
# Fetching 16 files:  88% 14/16 [01:50<00:40, 20.10s/it]
# Downloading: 100% 522/522 [00:00<00:00, 455kB/s]
# Fetching 16 files:  94% 15/16 [01:53<00:14, 14.76s/it]
# Downloading:   0% 0.00/335M [00:00<?, ?B/s]
# Downloading:   2% 7.14M/335M [00:00<00:04, 71.3MB/s]
# Downloading:   4% 14.9M/335M [00:00<00:04, 75.3MB/s]
# Downloading:   7% 22.5M/335M [00:00<00:05, 57.9MB/s]
# Downloading:   9% 30.1M/335M [00:00<00:04, 64.1MB/s]
# Downloading:  11% 37.9M/335M [00:00<00:04, 68.4MB/s]
# Downloading:  13% 45.0M/335M [00:00<00:04, 67.6MB/s]
# Downloading:  16% 53.0M/335M [00:00<00:03, 71.5MB/s]
# Downloading:  18% 60.8M/335M [00:00<00:03, 73.4MB/s]
# Downloading:  20% 68.3M/335M [00:00<00:03, 74.0MB/s]
# Downloading:  23% 76.2M/335M [00:01<00:03, 75.3MB/s]
# Downloading:  25% 84.0M/335M [00:01<00:03, 76.4MB/s]
# Downloading:  27% 91.7M/335M [00:01<00:03, 76.2MB/s]
# Downloading:  30% 99.8M/335M [00:01<00:03, 77.6MB/s]
# Downloading:  32% 108M/335M [00:01<00:02, 78.6MB/s]
# Downloading:  35% 116M/335M [00:01<00:02, 76.6MB/s]
# Downloading:  37% 123M/335M [00:01<00:03, 65.7MB/s]
# Downloading:  39% 131M/335M [00:01<00:02, 68.6MB/s]
# Downloading:  41% 139M/335M [00:01<00:02, 71.0MB/s]
# Downloading:  44% 147M/335M [00:02<00:02, 72.6MB/s]
# Downloading:  46% 154M/335M [00:02<00:02, 68.8MB/s]
# Downloading:  48% 162M/335M [00:02<00:02, 71.5MB/s]
# Downloading:  51% 170M/335M [00:02<00:02, 73.4MB/s]
# Downloading:  53% 177M/335M [00:02<00:02, 72.8MB/s]
# Downloading:  55% 184M/335M [00:02<00:02, 69.9MB/s]
# Downloading:  57% 192M/335M [00:02<00:02, 70.3MB/s]
# Downloading:  59% 199M/335M [00:02<00:02, 67.1MB/s]
# Downloading:  62% 206M/335M [00:02<00:01, 70.0MB/s]
# Downloading:  64% 213M/335M [00:02<00:01, 69.9MB/s]
# Downloading:  66% 220M/335M [00:03<00:01, 67.9MB/s]
# Downloading:  68% 228M/335M [00:03<00:01, 70.4MB/s]
# Downloading:  70% 236M/335M [00:03<00:01, 71.9MB/s]
# Downloading:  73% 244M/335M [00:03<00:01, 74.0MB/s]
# Downloading:  75% 251M/335M [00:03<00:01, 74.7MB/s]
# Downloading:  77% 259M/335M [00:03<00:01, 70.3MB/s]
# Downloading:  79% 266M/335M [00:03<00:00, 70.3MB/s]
# Downloading:  82% 273M/335M [00:03<00:00, 72.2MB/s]
# Downloading:  84% 281M/335M [00:03<00:00, 72.8MB/s]
# Downloading:  86% 288M/335M [00:04<00:00, 70.0MB/s]
# Downloading:  88% 296M/335M [00:04<00:00, 72.1MB/s]
# Downloading:  91% 303M/335M [00:04<00:00, 72.4MB/s]
# Downloading:  93% 311M/335M [00:04<00:00, 73.6MB/s]
# Downloading:  95% 318M/335M [00:04<00:00, 62.3MB/s]
# Downloading:  97% 325M/335M [00:04<00:00, 64.5MB/s]
# Downloading: 100% 335M/335M [00:04<00:00, 70.6MB/s]
# Fetching 16 files: 100% 16/16 [01:59<00:00,  7.45s/it]
# Generating class images: 100% 5/5 [02:56<00:00, 35.27s/it]
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 909kB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 565kB/s]
# Downloading: 100% 472/472 [00:00<00:00, 369kB/s]
# Downloading: 100% 806/806 [00:00<00:00, 657kB/s]
# Downloading: 100% 592/592 [00:00<00:00, 451kB/s]
# Downloading: 100% 492M/492M [00:06<00:00, 70.6MB/s]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:99: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   f'{candidate_env_vars["LD_LIBRARY_PATH"]} did not contain '
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:21: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('{"kernelManagerProxyPort"'), PosixPath('["--ip=172.28.0.2"],"debugAdapterMultiplexerPath"'), PosixPath('"172.28.0.3","jupyterArgs"'), PosixPath('true}'), PosixPath('6000,"kernelManagerProxyHost"'), PosixPath('"/usr/local/bin/dap_multiplexer","enableLsp"')}
#   "WARNING: The following directories listed in your path were found to "
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:21: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   "WARNING: The following directories listed in your path were found to "
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:21: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   "WARNING: The following directories listed in your path were found to "
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 112
# CUDA SETUP: Loading binary /usr/local/lib/python3.7/dist-packages/bitsandbytes/libbitsandbytes_cuda112.so...
# Caching latents: 100% 20/20 [00:14<00:00,  1.43it/s]
# Steps: 100% 900/900 [14:59<00:00,  1.01it/s, loss=0.28, lr=5e-6]
# Fetching 16 files: 100% 16/16 [00:00<00:00, 14260.28it/s]
# Steps: 100% 900/900 [15:34<00:00,  1.04s/it, loss=0.28, lr=5e-6]

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Download script
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py

# %%
#@markdown Run conversion.
ckpt_path = OUTPUT_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB), might loose some quality.
fp16 = False #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $OUTPUT_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at /content/drive/MyDrive/stable_diffusion_weights/tony/model.ckpt

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline
from IPython.display import display

model_path = OUTPUT_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16).to("cuda")
g_cuda = None
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 52362 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "photo of tony guy as a one piece character" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 7.5 #@param {type:"number"}
num_inference_steps = 50 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe([prompt] * num_samples, height=height, width=width, num_inference_steps=num_inference_steps, guidance_scale=guidance_scale, generator=g_cuda).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F7D8BBD8650>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F7D8BBD8250>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F7D8BBD8690>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F7D8BBD8B10>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
            [prompt]*int(num_samples), height=int(height), width=int(width),
            num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
            generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of sks guy, digital painting")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=50)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://16480.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://16480.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]

# %%
#@title (Optional) Delete diffuser weights and only keep the ckpt to free up drive space (4GB).

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
for f in glob(OUTPUT_DIR+"/*"):
    if not f.endswith(".ckpt"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)
